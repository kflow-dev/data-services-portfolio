# %% [markdown]
# # Advanced Data Drift Detection & Model Monitoring
#
# ## Statistical Tests, Change Point Detection, and Concept Drift Handling
#
# This notebook implements comprehensive drift detection for ML systems:
#
# - **Feature Drift**: PSI, Kolmogorov-Smirnov test, Population Stability Index
# - **Label Drift**: Distribution shift detection
# - **Concept Drift**: ADWIN, DDM/EDDM, Bayesian online change detection
# - **Drift Attribution**: Which features contribute most to drift?
# - **Response Strategies**: Retrain, adapt, or ignore
# - **Time Series Drift**: Rolling window analysis

# %%
import numpy as np
import pandas as pd
from typing import List, Dict, Tuple, Optional
from scipy import stats
from scipy.stats import ks_2samp, chisquare
import warnings
warnings.filterwarnings('ignore')

print("Drift detection libraries loaded")
print(f"NumPy: {np.__version__}")
