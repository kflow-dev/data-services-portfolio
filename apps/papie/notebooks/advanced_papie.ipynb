# %% [markdown]
# # Advanced Chatbot Dialogue Management & Personal Assistant
#
# ## Intent Classification, Entity Recognition, Context-Aware Responses, and Multi-Turn Dialogue
#
# This notebook implements an intelligent personal assistant:
#
# - **Intent Classification**: Transformer-based NLU
# - **Entity Recognition**: NER for extracting key information
# - **Dialogue State Tracking**: Context management across turns
# - **Response Generation**: Template + NLG hybrid approach
# - **Personalization**: User preference learning and adaptation
# - **Multi-Modal Support**: Text + voice + action capabilities

# %%
import numpy as np
import pandas as pd
from typing import List, Dict, Tuple
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
import warnings
warnings.filterwarnings('ignore')

print("Chatbot libraries loaded")
